# %%
from langchain.agents import create_agent
from langchain.chat_models import init_chat_model
from langchain_openai import ChatOpenAI

model = ChatOpenAI(model="gpt-4")



create_agent(model)
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[2], line 5
#       1 from langchain.agents import create_agent
#       2 from langchain.chat_models import init_chat_model
#       3 from langchain_openai import ChatOpenAI
#       4
# ----> 5 model = ChatOpenAI(model="gpt-4")
#       6
#       7
#       8
#
# File D:\code\food-recipe-recommender\.venv\Lib\site-packages\langchain_core\load\serializable.py:118, in Serializable.__init__(self, *args, **kwargs)
#     116 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     117     """"""  # noqa: D419  # Intentional blank docstring
# --> 118     super().__init__(*args, **kwargs)
#
#     [... skipping hidden 1 frame]
#
# File D:\code\food-recipe-recommender\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:1253, in BaseChatOpenAI.validate_environment(self)
#    1239         self.http_async_client = _build_proxied_async_httpx_client(
#    1240             proxy=self.openai_proxy,
#    1241             verify=global_ssl_context,
#    1242             socket_options=resolved_socket_options,
#    1243         )
#    1244     async_specific = {
#    1245         "http_client": self.http_async_client
#    1246         or _get_default_async_httpx_client(
#    (...)   1251         "api_key": async_api_key_value,
#    1252     }
# -> 1253     self.root_async_client = openai.AsyncOpenAI(
#    1254         **client_params,
#    1255         **async_specific,  # type: ignore[arg-type]
#    1256     )
#    1257     self.async_client = self.root_async_client.chat.completions
#    1258 return self
#
# File D:\code\food-recipe-recommender\.venv\Lib\site-packages\openai\_client.py:700, in AsyncOpenAI.__init__(self, api_key, admin_api_key, workload_identity, organization, project, webhook_secret, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation, _enforce_credentials)
#     691 self.admin_api_key = admin_api_key
#     693 if (
#     694     _enforce_credentials
#     695     and not self.api_key
#    (...)    698     and self.admin_api_key is None
#     699 ):
# --> 700     raise OpenAIError(
#     701         "Missing credentials. Please pass an `api_key`, `workload_identity`, `admin_api_key`, or set the `OPENAI_API_KEY` or `OPENAI_ADMIN_KEY` environment variable."
#     702     )
#     704 if organization is None:
#     705     organization = os.environ.get("OPENAI_ORG_ID")
#
# OpenAIError: Missing credentials. Please pass an `api_key`, `workload_identity`, `admin_api_key`, or set the `OPENAI_API_KEY` or `OPENAI_ADMIN_KEY` environment variable.
