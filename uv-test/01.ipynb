# %%
import os
import sys
from langchain.chat_models import init_chat_model
# 加载环境变量
from dotenv import load_dotenv
# 导入Langchain的初始化模型的函数

load_dotenv(override=True)

base_url = os.getenv('DASHSCOPE_BASE_URL')
print(base_url)

api_key = os.getenv('DASHSCOPE_API_KEY')
print(api_key)
model = os.getenv('DASHSCOPE_MODEL_ID')
print(model)
# Out:
# https://coding.dashscope.aliyuncs.com/v1
# sk-sp-31174fd20a2b4775ac6ee25a4ee8a347
# qwen3.5-plus

# %%
from langchain_core.messages import HumanMessage
from langchain.agents import create_agent
from langchain.chat_models import init_chat_model
import os

# 1.初始化模型
model = init_chat_model(
    model=model,  # 这里选择qwen3.5-plus，这是一个多模态模型，支持图片、文本、音频、视频
    model_provider="openai",
    base_url=base_url,
    api_key=api_key
)

print(type(model))

# 2.创建智能体
agent = create_agent(model=model)

# 3.组织多模态消息
multimodal_message = HumanMessage(
    content=[
        {"type": "image",
         "url": "https://help-static-aliyun-doc.aliyuncs.com/file-manage-files/zh-CN/20241022/emyrja/dog_and_girl.jpeg"},
        {"type": "text", "text": "这些图描绘了什么内容？"}
    ])

# 4.调用Agent，发送多模态消息
for token, metadata in agent.stream({
    "messages": [multimodal_message]
}, stream_mode="messages"):
    if token.content:
        print(token.content, end="", flush=True)
# Out:
# <class 'langchain_openai.chat_models.base.ChatOpenAI'>
# 这张图片描绘了一个非常温馨、和谐的场景，主要内容如下：
#
# 1.  **人物与动物**：
#     *   **女孩**：一位年轻女子坐在沙滩上，她留着长发，身穿一件黑白格子的衬衫和深色长裤（裤脚卷起）。她面带微笑，看起来非常开心。
#     *   **狗**：一只浅金色的大型犬（看起来像是拉布拉多或金毛寻回犬）坐在女孩对面。它身上戴着一条带有彩色花纹的胸背带。
#
# 2.  **互动动作**：
#     *   狗正抬起它的一只前爪，女孩伸出手掌与它的爪子相触。这看起来像是他们在玩“握手”的游戏，或者是在击掌（High-five）。这是一种充满信任和亲密感的互动。
#
# 3.  **环境与背景**：
#     *   场景设定在**海滩**上，背景可以看到平静的大海和微微涌起的海浪。
#     *   沙滩上有许多脚印和纹理。
#     *   在狗的身后，有一条红色的牵引绳散落在沙地上。
#
# 4.  **光影与氛围**：
#     *   光线非常柔和且温暖，从画面右侧照射过来（看起来像是日落时分或清晨的“黄金时刻”），给女孩的发丝和侧脸镀上了一层金色的光晕。
#     *   整体氛围显得宁静、快乐且充满爱意，展现了人与宠物之间美好的陪伴时光。
