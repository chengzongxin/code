# %%
import os
import sys
from langchain.chat_models import init_chat_model
# 加载环境变量
from dotenv import load_dotenv
# 导入Langchain的初始化模型的函数

load_dotenv(override=True)

base_url = os.getenv('DASHSCOPE_BASE_URL')
print(base_url)

api_key = os.getenv('DASHSCOPE_API_KEY')
print(api_key)
model = os.getenv('DASHSCOPE_MODEL_ID')
print(model)
# Out:
# https://coding.dashscope.aliyuncs.com/v1
# sk-sp-31174fd20a2b4775ac6ee25a4ee8a347
# qwen3.5-plus

# %%
from langchain_core.messages import HumanMessage
from langchain.agents import create_agent
from langchain.chat_models import init_chat_model
import os

# 1.初始化模型
model = init_chat_model(
    model=model,  # 这里选择qwen3.5-plus，这是一个多模态模型，支持图片、文本、音频、视频
    model_provider="openai",
    base_url=base_url,
    api_key=api_key
)

print(type(model))

# 2.创建智能体
agent = create_agent(model=model)

# 3.组织多模态消息
multimodal_message = HumanMessage(
    content=[
        {"type": "image",
         "url": "https://help-static-aliyun-doc.aliyuncs.com/file-manage-files/zh-CN/20241022/emyrja/dog_and_girl.jpeg"},
        {"type": "text", "text": "这些图描绘了什么内容？"}
    ])

# 4.调用Agent，发送多模态消息
for token, metadata in agent.stream({
    "messages": [multimodal_message]
}, stream_mode="messages"):
    if token.content:
        print(token.content, end="", flush=True)
# Out:
# <class 'langchain_openai.chat_models.base.ChatOpenAI'>
# 这张图片描绘了一个非常温馨、宁静的场景，主要包含以下内容：
#
# 1.  **人物与动物**：
#     *   **一位年轻女性**：她留着长发，身穿黑白格纹衬衫和深色长裤（裤脚卷起），正坐在沙滩上。她面带微笑，看起来非常开心。
#     *   **一只狗**：看起来像是一只金毛寻回犬或拉布拉多，毛色呈浅金色。它戴着带有彩色图案的胸背带，正乖巧地坐着。
#
# 2.  **动作与互动**：
#     *   狗狗抬起了一只前爪，搭在女子的手上，看起来像是在和主人**“握手”**或者**“击掌”**。
#     *   女子的一只手握着狗的爪子，另一只手似乎拿着小零食或者正准备抚摸它，两人（一人一狗）正在进行亲密的互动。
#
# 3.  **环境与氛围**：
#     *   **地点**：是在海边的沙滩上，背景可以看到海浪正在拍打岸边。
#     *   **光线**：阳光从画面右侧照射过来（看起来像是日落或日出时的“黄金时刻”），给女子的头发和侧脸镀上了一层温暖的金色光晕。
#     *   **整体感觉**：画面色调柔和温暖，传达出一种和谐、快乐以及人与宠物之间深厚羁绊的感觉。
